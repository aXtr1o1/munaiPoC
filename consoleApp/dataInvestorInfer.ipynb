# %%
import pandas as pd
import numpy as np
import openai
import faiss

# %%
f = open('apiKey.bin', 'r')
apiKey = f.read()

# %%
openai.api_key =apiKey
f.close()

# %%
embeddings = np.load('embeddingData/investorEmbeddings.npy')

# %%
def build_faiss_index(embeddings):
    dimension = embeddings.shape[1]
    index = faiss.IndexFlatL2(dimension)
    index.add(embeddings)
    return index

index = build_faiss_index(embeddings)

# %%
index
# Out:
# <faiss.swigfaiss_avx2.IndexFlatL2; proxy of <Swig Object of type 'faiss::IndexFlatL2 *' at 0x2db6fa220> >

# %%
def search_faiss(query, index, k=17):
    query_embedding = get_batch_embeddings([query])
    distances, indices = index.search(query_embedding, k)
    return indices[0], distances[0]

# %%
def get_batch_embeddings(texts, model="text-embedding-ada-002"):
    response = openai.Embedding.create(input=texts, model=model)
    return np.array([data['embedding'] for data in response['data']])

# %%
def query_gpt_4o_mini(query, retrieved_indices, df):
    retrieved_data = "\n".join([str(df.iloc[idx].to_dict()) for idx in retrieved_indices])
    
    prompt = f"""
    You are an expert AI assistant specialized in analyzing investors data. Your task is to provide concise, relevant, and actionable answers to the user query based on the provided data.

    Data context:
    {retrieved_data}

    User Query: "{query}"

    Your answer should directly address the user's query based on the context and data provided. If the answer is not explicitly found, provide the most relevant information or indicate uncertainty.
    """
    
    response = openai.ChatCompletion.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a highly efficient AI assistant focused on delivering quick and accurate responses related to investors data."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.2,
        max_tokens=150, 
        top_p=1.0, 
        frequency_penalty=0.0, 
        presence_penalty=0.0 
    )
    
    return response['choices'][0]['message']['content']

# %%
def perform_query(query, index, df):
    indices, distances = search_faiss(query, index)
    answer = query_gpt_4o_mini(query, indices, df)
    return answer

# %%
df = pd.read_csv('dataStuff/synthDataInvestor.csv')
df
# Out:
#           Full Name                               Email    Phone Number  \
# 0    Kavya Srinivas        kavya.srinivas@fundgroup.com  +91 9319083963
# 1      Gokul Talwar        gokul.talwar@visiongroup.com  +91 7655411811
# 2      Ayesha Bandi    ayesha.bandi@summitsyndicate.com  +91 9603448258
# 3      Renee Shetty       renee.shetty@nexuscapital.com  +91 9358440299
# 4    Drishya Badami  drishya.badami@growthsyndicate.com  +91 9930194644
# ..              ...                                 ...             ...
# 995     Suhana Mall        suhana.mall@fundholdings.com  +91 6445640374
# 996    Bhamini Char     bhamini.char@summitadvisors.com  +91 7749990454
# 997       Arnav Rau       arnav.rau@capitalpartners.com  +91 8719003870
# 998   Divyansh Wali     divyansh.wali@growthcapital.com  +91 9029812904
# 999  Anahita Kapoor    anahita.kapoor@nexuspartners.com  +91 9719468375
#
#     How do you like to Invest as        Company Name         Designation  \
# 0                     Individual     Wealth Advisors          VC Partner
# 1                     Individual     Summit Advisors            Investor
# 2                  Family Office       Fund Partners  Investment Analyst
# 3                           Firm  Growth Investments            Director
# 4                     Individual    Growth Syndicate          VC Partner
# ..                           ...                 ...                 ...
# 995                         Firm     Nexus Syndicate                 CEO
# 996                Family Office       Nexus Capital    Managing Partner
# 997                Family Office   Ventures Partners  Investment Analyst
# 998                   Individual  Ventures Syndicate            Director
# 999                Family Office     Summit Advisors  Investment Analyst
#
#                            Primary Sectors of Interest  \
# 0    Health Care, Technology - STEM Based, Impact I...
# 1    Infrastructure & Manufacturing, Health Care, I...
# 2    Health Care, Information Technology, Impact In...
# 3                    Deep Tech, Information Technology
# 4    Infrastructure & Manufacturing, ESG (Environme...
# ..                                                 ...
# 995  Health Care, Infrastructure & Manufacturing, E...
# 996  Technology - STEM Based, ESG (Environmental, S...
# 997  Technology - STEM Based, Infrastructure & Manu...
# 998  Technology - STEM Based, ESG (Environmental, S...
# 999                            Technology - STEM Based
#
#     Stage of Startup Preferred Preferred Ticket Size of Investment  \
# 0           Early Growth Stage                 5 Lakhs to 10 Lakhs
# 1                       Growth                 5 Lakhs to 10 Lakhs
# 2                       Growth                25 Lakhs to 50 Lakhs
# 3      MVP/Prototype Developed                 50 Lakhs to 1 Crore
# 4      MVP/Prototype Developed                10 Lakhs to 25 Lakhs
# ..                         ...                                 ...
# 995         Early Growth Stage                25 Lakhs to 50 Lakhs
# 996         Early Growth Stage                 50 Lakhs to 1 Crore
# 997                     Growth                25 Lakhs to 50 Lakhs
# 998         Early Growth Stage                25 Lakhs to 50 Lakhs
# 999                     Growth                 50 Lakhs to 1 Crore
#
#      No of Startups to invest in this quarter  \
# 0                                          10
# 1                                           5
# 2                                           5
# 3                                           3
# 4                                           9
# ..                                        ...
# 995                                         1
# 996                                         1
# 997                                         2
# 998                                         7
# 999                                         2
#
#                       Aware of compliance requirements  \
# 0    I have some knowledge but would appreciate fur...
# 1    I have some knowledge but would appreciate fur...
# 2    Yes, I am familiar with the compliance require...
# 3    I have some knowledge but would appreciate fur...
# 4    I have some knowledge but would appreciate fur...
# ..                                                 ...
# 995  I have some knowledge but would appreciate fur...
# 996  I have some knowledge but would appreciate fur...
# 997  No, I am not familiar with the compliance requ...
# 998  I have some knowledge but would appreciate fur...
# 999  No, I am not familiar with the compliance requ...
#
#                           Experience Level as Investor  \
# 0    I have invested in a few startup ventures in t...
# 1    I regularly invest in startup ventures as part...
# 2    I have invested in a few startup ventures in t...
# 3    This is my first time considering Investment i...
# 4    I regularly invest in startup ventures as part...
# ..                                                 ...
# 995  This is my first time considering Investment i...
# 996  This is my first time considering Investment i...
# 997  I regularly invest in startup ventures as part...
# 998  I have invested in a few startup ventures in t...
# 999  I have invested in a few startup ventures in t...
#
#     Want Startup Singam Support?  \
# 0                            Yes
# 1                            Yes
# 2                            Yes
# 3                            Yes
# 4                             No
# ..                           ...
# 995                          Yes
# 996                           No
# 997                           No
# 998                          Yes
# 999                           No
#
#                                    Additional Comments
# 0          Would like to explore ESG-focused startups.
# 1    Looking for disruptive startups in the infrast...
# 2      Looking for impact-driven startups in AgriTech.
# 3      Looking for impact-driven startups in AgriTech.
# 4    Interested in D2C brands with a strong custome...
# ..                                                 ...
# 995  Focused on deep-tech innovations with sustaina...
# 996  Focused on deep-tech innovations with sustaina...
# 997  Looking for disruptive startups in the infrast...
# 998  Prefer startups with proven traction before in...
# 999        Would like to explore ESG-focused startups.
#
# [1000 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['Full Name', 'Email', 'Phone Number', 'How do you like to Invest as',
#        'Company Name', 'Designation', 'Primary Sectors of Interest',
#        'Stage of Startup Preferred', 'Preferred Ticket Size of Investment',
#        'No of Startups to invest in this quarter',
#        'Aware of compliance requirements', 'Experience Level as Investor',
#        'Want Startup Singam Support?', 'Additional Comments'],
#       dtype='object')

# %%
query = "I need the List of Investors that prefer Technology & manufacturing sector"

# %%
outResult = perform_query(query, index, df)
outResult
# Out:
# 'Here is the list of investors that prefer the Technology and Manufacturing sector:\n\n1. **Dharmajan Taneja**\n   - Email: dharmajan.taneja@nexusadvisors.com\n   - Phone Number: +91 6955924702\n   - Primary Sectors of Interest: AgriTech, Infrastructure & Manufacturing, Technology - STEM Based\n\n2. **Priyansh Gill**\n   - Email: priyansh.gill@capitalholdings.com\n   - Phone Number: +91 6615280201\n   - Primary Sectors of Interest: Infrastructure & Manufacturing, Technology - STEM Based, Health Care\n\n3. **Taran Bhalla**\n   - Email: taran.bhalla'
